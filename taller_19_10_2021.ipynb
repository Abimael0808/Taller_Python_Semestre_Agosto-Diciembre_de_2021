# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
# Out:
# El valor es igual a 30

# %%
a = 20

if a == 30:
    print("El valor es igual a 30")

# %%
a = 20

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
# Out:
# El valor es igual a 30

# %%
a = 31

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
# Out:
# El valor es mayor a 30

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es igual a 30

# %%
a = 31

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es mayor a 30

# %%
a = 29

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es menor a 30

# %%
a = 49
if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# El valor es menor a 50

# %%
a = input("Ingrese el número que desea comparar")


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c9d45c63545b> in <module>
#       4 if a == 50:
#       5     print("El valor es igual a 50")
# ----> 6 elif a > 50:
#       7     print("El valor es mayor a 50")
#       8 else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar10
# El valor es menor a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar20
# El valor es menor a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar20
# El valor es menor a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar10
# El valor es menor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar56
# El valor es mayor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar60
# El valor es mayor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar40
# El valor es menor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar60
# El valor es mayor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar70
# El valor es mayor a 50
