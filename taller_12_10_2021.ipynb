# %%
print("Hola Mundo !!!")
# Out:
# Hola Mundo !!!

# %%
# hacer una suma
# los toma como string a y b y concatena
a = input("Dame el valor de a: ")
b = input("Dame el valor de b: ")
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a: 50
# Dame el valor de b: 200
# El resultado es:  50200

# %%
print("hola " + "mundo ")
# Out:
# hola mundo

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a: 50
# Dame el valor de b: 10
# El resultado es:  60.0

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es:  %.2f " %(r) )
# Out:
# Dame el valor de a: 10
# Dame el valor de b: 300
# El resultado es:  310.00

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.2f resultado es:  %.2f " %(r, r) )
# Out:
# Dame el valor de a: 200
# Dame el valor de b: 205
# El 405.00 resultado es:  405.00

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.1f resultado es:  %.3f " %(r, r) )
# Out:
# Dame el valor de a: 20
# Dame el valor de b: 47
# El 67.0 resultado es:  67.000

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("El valor en millas es:  %.3f " %(millas) )
# Out:
# Dame el número de kilómetros: 200
# El valor en millas es:  124.274

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f " %(k, millas) )
# Out:
# Dame el número de kilómetros: 500
# 500.0 Kilometro(s) equivale a: 310.69

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilometros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# Dame el número de kilometros: 450
# 450.0 Kilometro(s) equivale a: 279.62 millas

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor

# le faltan los dos puntos en el else
if millas = 10:
    print("Meta no cumplida")
else
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
#   File "<ipython-input-11-cff136281f8c>", line 9
#     if millas = 10:
#               ^
# SyntaxError: invalid syntax

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ? 10
# 10.0 Kilometro(s) equivale a: 6.21 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ? 200
# 200.0 Kilometro(s) equivale a: 124.27 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ? 16
# 16.0 Kilometro(s) equivale a: 9.94 millas
# Meta cunplida
